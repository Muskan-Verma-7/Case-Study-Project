# %%
import pandas as pd

# %%
data = pd.read_csv("cleaned_sickness_table.csv")

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1152 entries, 0 to 1151
# Data columns (total 27 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   date                      1152 non-null   object
#  1   n_sick                    1152 non-null   int64
#  2   calls                     1152 non-null   int64
#  3   n_duty                    1152 non-null   int64
#  4   n_sby                     1152 non-null   int64
#  5   sby_need                  1152 non-null   int64
#  6   dafted                    1152 non-null   int64
#  7   year                      1152 non-null   int64
#  8   month                     1152 non-null   int64
#  9   day                       1152 non-null   int64
#  10  day_of_week               1152 non-null   int64
#  11  is_weekend                1152 non-null   int64
#  12  quarter                   1152 non-null   int64
#  13  n_sick_lag1               1152 non-null   int64
# ...

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns


# Set up the figure and axes
fig, axes = plt.subplots(nrows=3, ncols=1, figsize=(15, 18))

# Monthly patterns for n_sick
sns.boxplot(data=data, x='month', y='n_sick', ax=axes[0])
axes[0].set_title('Monthly Distribution of Drivers who called in Sick')
axes[0].set_xticklabels(['Jan', 'Feb', 'Mar', 'Apr', 'May', 'Jun', 'Jul', 'Aug', 'Sep', 'Oct', 'Nov', 'Dec'])

# Monthly patterns for calls
sns.boxplot(data=data, x='month', y='calls', ax=axes[1])
axes[1].set_title('Monthly Distribution of Emergency Calls')
axes[1].set_xticklabels(['Jan', 'Feb', 'Mar', 'Apr', 'May', 'Jun', 'Jul', 'Aug', 'Sep', 'Oct', 'Nov', 'Dec'])

# Monthly patterns for sby_need
sns.boxplot(data=data, x='month', y='sby_need', ax=axes[2])
axes[2].set_title('Monthly Distribution of Standbys Activated')
axes[2].set_xticklabels(['Jan', 'Feb', 'Mar', 'Apr', 'May', 'Jun', 'Jul', 'Aug', 'Sep', 'Oct', 'Nov', 'Dec'])

# Adjust the layout
plt.tight_layout()
plt.show()
# Out:
# C:\Users\s9\AppData\Local\Temp\ipykernel_6168\3047795415.py:12: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   axes[0].set_xticklabels(['Jan', 'Feb', 'Mar', 'Apr', 'May', 'Jun', 'Jul', 'Aug', 'Sep', 'Oct', 'Nov', 'Dec'])
# C:\Users\s9\AppData\Local\Temp\ipykernel_6168\3047795415.py:17: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   axes[1].set_xticklabels(['Jan', 'Feb', 'Mar', 'Apr', 'May', 'Jun', 'Jul', 'Aug', 'Sep', 'Oct', 'Nov', 'Dec'])
# C:\Users\s9\AppData\Local\Temp\ipykernel_6168\3047795415.py:22: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   axes[2].set_xticklabels(['Jan', 'Feb', 'Mar', 'Apr', 'May', 'Jun', 'Jul', 'Aug', 'Sep', 'Oct', 'Nov', 'Dec'])

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns


# Set up the figure and axes
fig, axes = plt.subplots(nrows=3, ncols=1, figsize=(15, 18))

# Weekly patterns for n_sick
sns.boxplot(data=data, x='day_of_week', y='n_sick', ax=axes[0], palette="Blues_d")
axes[0].set_title('Weekly Distribution of Drivers who called in Sick')
axes[0].set_xticklabels(['Mon', 'Tue', 'Wed', 'Thu', 'Fri', 'Sat', 'Sun'])

# Weekly patterns for calls
sns.boxplot(data=data, x='day_of_week', y='calls', ax=axes[1], palette="Oranges_d")
axes[1].set_title('Weekly Distribution of Emergency Calls')
axes[1].set_xticklabels(['Mon', 'Tue', 'Wed', 'Thu', 'Fri', 'Sat', 'Sun'])

# Weekly patterns for sby_need
sns.boxplot(data=data, x='day_of_week', y='sby_need', ax=axes[2], palette="Greens_d")
axes[2].set_title('Weekly Distribution of Standbys Activated')
axes[2].set_xticklabels(['Mon', 'Tue', 'Wed', 'Thu', 'Fri', 'Sat', 'Sun'])

# Adjust the layout
plt.tight_layout()
plt.show()
# Out:
# C:\Users\s9\AppData\Local\Temp\ipykernel_6168\2612513970.py:10: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(data=data, x='day_of_week', y='n_sick', ax=axes[0], palette="Blues_d")
# C:\Users\s9\AppData\Local\Temp\ipykernel_6168\2612513970.py:12: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   axes[0].set_xticklabels(['Mon', 'Tue', 'Wed', 'Thu', 'Fri', 'Sat', 'Sun'])
# C:\Users\s9\AppData\Local\Temp\ipykernel_6168\2612513970.py:15: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(data=data, x='day_of_week', y='calls', ax=axes[1], palette="Oranges_d")
# ...

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns



# Set up the figure and axes
fig, axes = plt.subplots(nrows=3, ncols=2, figsize=(18, 15))

# Scatter plots for relationships with 'sby_need'
sns.scatterplot(data=data, x='n_sick', y='sby_need', ax=axes[0, 0], alpha=0.5, color='blue')
axes[0, 0].set_title('Relationship between Drivers Sick and Standbys Activated')

sns.scatterplot(data=data, x='calls', y='sby_need', ax=axes[1, 0], alpha=0.5, color='orange')
axes[1, 0].set_title('Relationship between Emergency Calls and Standbys Activated')

sns.scatterplot(data=data, x='n_duty', y='sby_need', ax=axes[2, 0], alpha=0.5, color='green')
axes[2, 0].set_title('Relationship between Drivers on Duty and Standbys Activated')

# Box plots for relationship of 'is_weekend', 'quarter', and 'day_of_week' with 'sby_need'
sns.boxplot(data=data, x='is_weekend', y='sby_need', ax=axes[0, 1], palette="coolwarm")
axes[0, 1].set_title('Distribution of Standbys Activated on Weekdays vs Weekends')
axes[0, 1].set_xticklabels(['Weekday', 'Weekend'])

sns.boxplot(data=data, x='month', y='sby_need', ax=axes[1, 1], palette="viridis")
axes[1, 1].set_title('Distribution of Standbys Activated across Months')
axes[1, 1].set_xticklabels(['Jan', 'Feb', 'Mar', 'Apr', 'May', 'Jun', 'Jul', 'Aug', 'Sep', 'Oct', 'Nov', 'Dec'])

sns.boxplot(data=data, x='day_of_week', y='sby_need', ax=axes[2, 1], palette="magma")
axes[2, 1].set_title('Distribution of Standbys Activated across Days of the Week')
axes[2, 1].set_xticklabels(['Mon', 'Tue', 'Wed', 'Thu', 'Fri', 'Sat', 'Sun'])

# Adjust the layout
plt.tight_layout()
plt.show()
# Out:
# C:\Users\s9\AppData\Local\Temp\ipykernel_6168\1070885020.py:21: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(data=data, x='is_weekend', y='sby_need', ax=axes[0, 1], palette="coolwarm")
# C:\Users\s9\AppData\Local\Temp\ipykernel_6168\1070885020.py:23: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   axes[0, 1].set_xticklabels(['Weekday', 'Weekend'])
# C:\Users\s9\AppData\Local\Temp\ipykernel_6168\1070885020.py:25: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(data=data, x='month', y='sby_need', ax=axes[1, 1], palette="viridis")
# ...

# %%
import pandas as pd
from scipy.stats import ttest_ind


# Separate the data into weekdays and weekends
weekdays_data = data[data['is_weekend'] == False]['sby_need']
weekends_data = data[data['is_weekend'] == True]['sby_need']

# Perform a t-test
t_stat, p_value = ttest_ind(weekdays_data, weekends_data)

t_stat, p_value
# Out:
# (4.366317452300835, 1.3773696947868493e-05)

# %% [markdown]
# Selecting Features

# %%
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler

# Load the data (assuming you've already done this step earlier)
# data = pd.read_csv('path_to_your_dataset.csv')

# Selecting features and target variable
features = data.drop(columns=['date', 'dafted', 'sby_need'])
target = data['sby_need']

# Splitting the dataset into training and testing sets (80% train, 20% test)
X_train, X_test, y_train, y_test = train_test_split(features, target, test_size=0.2, random_state=42)

# Standardizing the data
scaler = StandardScaler()
X_train_scaled = scaler.fit_transform(X_train)
X_test_scaled = scaler.transform(X_test)  # We only transform the test set based on the training set's parameters

# %% [markdown]
# Baseline Model: Linear Regression

# %%
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error
import numpy as np

# Initialize the Linear Regression model
lr_model = LinearRegression()

# Train the model on the standardized training data
lr_model.fit(X_train_scaled, y_train)

# Predict on the standardized test set
y_pred = lr_model.predict(X_test_scaled)

# Evaluate the model's performance using RMSE
rmse = np.sqrt(mean_squared_error(y_test, y_pred))

print(f"RMSE: {rmse}")
# Out:
# RMSE: 50.68627347777826

# %% [markdown]
# Random Forest Regressor

# %%
from sklearn.ensemble import RandomForestRegressor
from sklearn.metrics import mean_squared_error
import numpy as np

# Initialize the Random Forest Regressor
rf_model = RandomForestRegressor(random_state=42, n_estimators=100)

# Train the model on the standardized training data
rf_model.fit(X_train_scaled, y_train)

# Predict on the standardized test set
y_pred_rf = rf_model.predict(X_test_scaled)

# Evaluate the model's performance using RMSE
rmse_rf = np.sqrt(mean_squared_error(y_test, y_pred_rf))

print(f"RMSE: {rmse_rf}")
# Out:
# RMSE: 4.52309829451209

# %%
import xgboost as xgb
from sklearn.metrics import mean_squared_error

# Initialize the XGBoost regressor
xgb_regressor = xgb.XGBRegressor(objective ='reg:squarederror', 
                                 n_estimators=100, 
                                 max_depth=6, 
                                 learning_rate=0.1, 
                                 seed=42)

# Train the model on the training data
xgb_regressor.fit(X_train_scaled, y_train)

# Predict on the test data
y_pred_xgb = xgb_regressor.predict(X_test_scaled)

# Calculate the RMSE for the XGBoost model
rmse_xgb = np.sqrt(mean_squared_error(y_test, y_pred_xgb))

print(f"RMSE for XGBoost Regressor: {rmse_xgb}")
# Out:
# RMSE for XGBoost Regressor: 3.7470715511268384

# %%
from sklearn.model_selection import RandomizedSearchCV
import numpy as np

# Define the hyperparameters and their possible values
param_dist_xgb = {
    'n_estimators': np.arange(50, 501, 50),
    'learning_rate': [0.01, 0.05, 0.1, 0.2, 0.3],
    'max_depth': np.arange(3, 21, 3),
    'subsample': np.linspace(0.5, 1.0, 6),
    'colsample_bytree': np.linspace(0.5, 1.0, 6),
    'colsample_bylevel': np.linspace(0.5, 1.0, 6),
    'gamma': np.linspace(0, 0.5, 6),
    'reg_alpha': [0, 0.001, 0.005, 0.01, 0.05, 0.1, 0.5, 1, 5, 10],
    'reg_lambda': [0, 0.001, 0.005, 0.01, 0.05, 0.1, 0.5, 1, 5, 10]
}

# Initialize the XGBoost Regressor
xgb_regressor = xgb.XGBRegressor(objective='reg:squarederror', seed=42)

# Set up the RandomizedSearchCV
xgb_random_search = RandomizedSearchCV(xgb_regressor, 
                                       param_distributions=param_dist_xgb, 
                                       n_iter=100, 
                                       cv=5, 
                                       verbose=1, 
                                       random_state=42, 
                                       n_jobs=-1)

# %%
# Fit the model (this step can be time-consuming depending on the dataset size and search space)
xgb_random_search.fit(X_train_scaled, y_train)

# After fitting, you can get the best hyperparameters using:
best_hyperparameters_xgb = xgb_random_search.best_params_
# Out:
# Fitting 5 folds for each of 100 candidates, totalling 500 fits

# %%
print(best_hyperparameters_xgb)
# Out:
# {'subsample': 0.7, 'reg_lambda': 0, 'reg_alpha': 1, 'n_estimators': 150, 'max_depth': 3, 'learning_rate': 0.1, 'gamma': 0.4, 'colsample_bytree': 0.8, 'colsample_bylevel': 1.0}

# %%
import xgboost as xgb
from sklearn.metrics import mean_squared_error

# Using the provided best hyperparameters to configure the XGBoost model
optimized_xgb_regressor = xgb.XGBRegressor(
    subsample=0.7, 
    reg_lambda=0, 
    reg_alpha=1, 
    n_estimators=150, 
    max_depth=3, 
    learning_rate=0.1, 
    gamma=0.4, 
    colsample_bytree=0.8, 
    colsample_bylevel=1.0,
    objective='reg:squarederror',
    seed=42
)

# Train the optimized model on the training data
optimized_xgb_regressor.fit(X_train_scaled, y_train)

# Predict on the test data
y_pred_optimized_xgb = optimized_xgb_regressor.predict(X_test_scaled)

# Calculate the RMSE for the optimized XGBoost model
rmse_optimized_xgb = np.sqrt(mean_squared_error(y_test, y_pred_optimized_xgb))

print(f"RMSE for Optimized XGBoost Regressor: {rmse_optimized_xgb}")
# Out:
# RMSE for Optimized XGBoost Regressor: 3.5079856297565244

# %%
import matplotlib.pyplot as plt

# 1. Train each model (if not already trained)

# Train the Linear Regression model
lr_model.fit(X_train_scaled, y_train)

# Train the Random Forest Regressor
rf_model.fit(X_train_scaled, y_train)

# Train the Original XGBoost Model (assuming it was defined earlier with default parameters)
xgb_regressor.fit(X_train_scaled, y_train)

# Train the Optimized XGBoost Model with the provided hyperparameters
optimized_xgb_regressor.fit(X_train_scaled, y_train)

# 2. Predict on the test set using each model
y_pred_lr = lr_model.predict(X_test_scaled)  # Baseline Model (Linear Regression)
y_pred_rf = rf_model.predict(X_test_scaled)  # Random Forest Regressor
y_pred_xgb_original = xgb_regressor.predict(X_test_scaled)  # Original XGBoost Model
y_pred_xgb_optimized = optimized_xgb_regressor.predict(X_test_scaled)  # Optimized XGBoost Model

# 3. Calculate the RMSE for each model's predictions
rmse_values = {
    'Linear Regression': np.sqrt(mean_squared_error(y_test, y_pred_lr)),
    'Random Forest': np.sqrt(mean_squared_error(y_test, y_pred_rf)),
    'XGBoost (Original)': np.sqrt(mean_squared_error(y_test, y_pred_xgb_original)),
    'XGBoost (Optimized)': np.sqrt(mean_squared_error(y_test, y_pred_xgb_optimized))
}

# 4. Visualize the RMSE values using a bar chart
plt.figure(figsize=(10, 6))
plt.bar(rmse_values.keys(), rmse_values.values(), color=['blue', 'green', 'yellow', 'red'])
plt.ylabel('RMSE')
plt.title('Model Comparison based on RMSE')
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt

# Calculate residuals for the optimized XGBoost model (can be done for other models similarly)
residuals_xgb_optimized = y_test - y_pred_xgb_optimized

# Plotting the residuals
plt.figure(figsize=(14, 6))

# Residual scatter plot
plt.subplot(1, 2, 1)
plt.scatter(y_test, residuals_xgb_optimized, alpha=0.5)
plt.axhline(y=0, color='r', linestyle='--')
plt.xlabel('Actual Values')
plt.ylabel('Residuals')
plt.title('Residuals vs. Actual Values')

# Histogram of residuals
plt.subplot(1, 2, 2)
plt.hist(residuals_xgb_optimized, bins=30, edgecolor='black')
plt.xlabel('Residual')
plt.ylabel('Frequency')
plt.title('Histogram of Residuals')

plt.tight_layout()
plt.show()

# %%
from sklearn.metrics import mean_absolute_error, mean_squared_error

# Predictions from the optimized XGBoost model
# (assuming you've already obtained them as y_pred_optimized_xgb)

# RMSE
rmse_optimized_xgb = np.sqrt(mean_squared_error(y_test, y_pred_optimized_xgb))

# MAE
mae_optimized_xgb = mean_absolute_error(y_test, y_pred_optimized_xgb)

# Display the metrics
print(f"RMSE for Optimized XGBoost Model: {rmse_optimized_xgb:.4f}")
print(f"MAE for Optimized XGBoost Model: {mae_optimized_xgb:.4f}")
# Out:
# RMSE for Optimized XGBoost Model: 3.5080
# MAE for Optimized XGBoost Model: 1.5654

# %%
# Extract feature importance from the optimized XGBoost model
feature_importance_optimized = optimized_xgb_regressor.feature_importances_

# Create a DataFrame for visualization
features_df = pd.DataFrame({
    'Feature': features.columns,
    'Importance': feature_importance_optimized
})

# Sort the features based on importance
features_df = features_df.sort_values(by='Importance', ascending=False)

# Plotting the feature importance
plt.figure(figsize=(12, 8))
plt.barh(features_df['Feature'], features_df['Importance'], color='skyblue')
plt.xlabel('Importance')
plt.ylabel('Feature')
plt.title('Feature Importance for Optimized XGBoost Model')
plt.gca().invert_yaxis()  # To display the most important feature at the top
plt.show()

# %%
import xgboost as xgb
from sklearn.metrics import mean_squared_error

# Define the hyperparameters based on the best ones obtained earlier, but adjust regularization
regularized_params = {
    'subsample': 0.7, 
    'reg_lambda': 5,  # Increase L2 regularization
    'reg_alpha': 5,   # Increase L1 regularization
    'n_estimators': 150, 
    'max_depth': 3, 
    'learning_rate': 0.1, 
    'gamma': 0.4, 
    'colsample_bytree': 0.8, 
    'colsample_bylevel': 1.0,
    'objective': 'reg:squarederror', 
    'seed': 42
}

# Initialize the XGBoost regressor with increased regularization
regularized_xgb_regressor = xgb.XGBRegressor(**regularized_params)

# Train the regularized model
regularized_xgb_regressor.fit(X_train_scaled, y_train)

# Predict on the test set
y_pred_regularized_xgb = regularized_xgb_regressor.predict(X_test_scaled)

# Calculate RMSE for the regularized model
rmse_regularized_xgb = np.sqrt(mean_squared_error(y_test, y_pred_regularized_xgb))
print(f"RMSE for Regularized XGBoost Model: {rmse_regularized_xgb:.4f}")
# Out:
# RMSE for Regularized XGBoost Model: 3.8119

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Extract feature importance from the regularized XGBoost model
feature_importance_regularized = regularized_xgb_regressor.feature_importances_

# Create a DataFrame for visualization
features_df_regularized = pd.DataFrame({
    'Feature': features.columns,
    'Importance': feature_importance_regularized
})

# Sort the features based on importance
features_df_regularized = features_df_regularized.sort_values(by='Importance', ascending=False)

# Plotting the feature importance
plt.figure(figsize=(12, 8))
plt.barh(features_df_regularized['Feature'], features_df_regularized['Importance'], color='skyblue')
plt.xlabel('Importance')
plt.ylabel('Feature')
plt.title('Feature Importance for Regularized XGBoost Model')
plt.gca().invert_yaxis()  # To display the most important feature at the top
plt.show()

# %% [markdown]
# Overfitting check for Regularized xgboost model

# %%
from sklearn.model_selection import learning_curve

def plot_learning_curve(model, X, y):
    train_sizes, train_scores, test_scores = learning_curve(model, X, y, cv=5, scoring="neg_mean_squared_error", 
                                                            train_sizes=np.linspace(0.1, 1.0, 10))
    
    train_mean = np.mean(-train_scores, axis=1)
    train_std = np.std(-train_scores, axis=1)
    test_mean = np.mean(-test_scores, axis=1)
    test_std = np.std(-test_scores, axis=1)

    plt.figure(figsize=(10, 6))
    plt.plot(train_sizes, train_mean, label="Training error")
    plt.plot(train_sizes, test_mean, label="Validation error")
    plt.fill_between(train_sizes, train_mean - train_std, train_mean + train_std, color="#DDDDDD")
    plt.fill_between(train_sizes, test_mean - test_std, test_mean + test_std, color="#DDDDDD")
    plt.title("Learning Curve")
    plt.xlabel("Number of Training Examples")
    plt.ylabel("MSE")
    plt.legend(loc="best")
    plt.grid()
    plt.show()

# Call the function
plot_learning_curve(regularized_xgb_regressor, X_train_scaled, y_train)

# %%
from sklearn.model_selection import learning_curve
import matplotlib.pyplot as plt
import numpy as np

def plot_learning_curve(model, X, y):
    train_sizes, train_scores, test_scores = learning_curve(model, X, y, cv=5, scoring="neg_mean_squared_error", 
                                                            train_sizes=np.linspace(0.1, 1.0, 10))
    
    train_mean = np.mean(-train_scores, axis=1)
    train_std = np.std(-train_scores, axis=1)
    test_mean = np.mean(-test_scores, axis=1)
    test_std = np.std(-test_scores, axis=1)

    plt.figure(figsize=(10, 6))
    plt.plot(train_sizes, train_mean, label="Training error")
    plt.plot(train_sizes, test_mean, label="Validation error")
    plt.fill_between(train_sizes, train_mean - train_std, train_mean + train_std, color="#DDDDDD")
    plt.fill_between(train_sizes, test_mean - test_std, test_mean + test_std, color="#DDDDDD")
    plt.title("Learning Curve for Optimized XGBoost Model")
    plt.xlabel("Number of Training Examples")
    plt.ylabel("MSE")
    plt.legend(loc="best")
    plt.grid()
    plt.show()

# Assuming you've already defined your optimized XGBoost model as 'optimized_xgb_regressor'
plot_learning_curve(optimized_xgb_regressor, X_train_scaled, y_train)

# %%
import numpy as np

# Assuming you've loaded your test data into variables named X_test and y_test
# and your optimized model is named 'optimized_xgb_regressor'

# Predicting the standby needs on the test data
predicted_sby_need = optimized_xgb_regressor.predict(X_test_scaled)

# Calculate the number of drivers that are "dafted" based on the predicted values
predicted_dafted = np.maximum(0, predicted_sby_need + X_test['n_sby'].values - y_test.values)

# Calculate the total number of insufficient standby days
insufficient_standby_days = np.sum(predicted_dafted > 0)

print(f"Total number of insufficient standby days: {insufficient_standby_days}")
# Out:
# Total number of insufficient standby days: 231

# %%
# Assuming you've loaded your data into a DataFrame named 'data'
# and your optimized model is named 'optimized_xgb_regressor'

# Prepare the features
features = data.drop(columns=['date', 'dafted', 'sby_need'])
features_scaled = scaler.transform(features)  # Use the same scaler that was fit on the training data

# Predict the number of standby drivers needed
predicted_sby_need = optimized_xgb_regressor.predict(features_scaled)

# Add the predictions to your DataFrame
data['predicted_sby_need'] = predicted_sby_need

# Display the results
print(data[['date', 'predicted_sby_need']])
# Out:
#             date  predicted_sby_need
# 0     01-04-2016            5.044970
# 1     02-04-2016           69.729179
# 2     03-04-2016            0.500926
# 3     04-04-2016            0.263590
# 4     05-04-2016            0.473050
# ...          ...                 ...
# 1147  23-05-2019            1.365281
# 1148  24-05-2019            0.460926
# 1149  25-05-2019          147.961517
# 1150  26-05-2019          158.476501
# 1151  27-05-2019           -0.056634
#
# [1152 rows x 2 columns]
